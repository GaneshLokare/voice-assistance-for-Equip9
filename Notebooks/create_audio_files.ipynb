# %% [markdown]
# # Create synthetic audio files

# %%
from gtts import gTTS

# text to be converted to speech
texts = ["Bulldozer","Bulldozers","Excavator","Excavators","Crane","cranes","JCB","JCB's","Roller","Rollers"]

# list of language codes for different accents
langs = ['en', 'es', 'fr', 'de', 'it', 'pt', 'ru', 'hi', 'ja', 'zh','af', 'sq', 'ar', 'hy', 'az', 'eu', 'be', 'bn', 'bs', 'bg', 'ca', 'ceb', 'ny', 'zh-cn', 'zh-tw', 'co', 'hr', 'cs', 'da', 'nl', 'eo', 'et', 'tl', 'fi', 'fr', 'fy', 'gl', 'ka', 'de', 'el', 'gu', 'ht', 'ha', 'haw', 'he', 'hi', 'hmn', 'hu', 'is', 'ig', 'id', 'ga', 'it', 'ja', 'jw', 'kn', 'kk', 'km', 'rw', 'ko', 'ku', 'ky', 'lo', 'la', 'lv', 'lt', 'lb', 'mk', 'mg', 'ms', 'ml', 'mt', 'mi', 'mr', 'mn', 'my', 'ne', 'no', 'or', 'ps', 'fa', 'pl', 'pt', 'pa', 'ro', 'ru', 'sm', 'gd', 'sr', 'st', 'sn', 'sd', 'si', 'sk', 'sl', 'so', 'es', 'su', 'sw', 'sv', 'tg', 'ta', 'tt', 'te', 'th', 'tr', 'tk', 'uk', 'ur', 'ug', 'uz', 'vi', 'cy', 'xh', 'yi', 'yo', 'zu']

# create a gTTS object for each language and save the audio as a file
for text in texts:
    for lang in langs:
        try:
            tts = gTTS(text=text, lang=lang)
            filename = f"excavators {text} {lang}.mp3"
            tts.save(filename)
            print(f"Saved audio file '{filename}' with accent '{lang}'")
        except:
            pass
# Out:
# Saved audio file 'excavators excavators en.mp3' with accent 'en'
# Saved audio file 'excavators excavators es.mp3' with accent 'es'
# Saved audio file 'excavators excavators fr.mp3' with accent 'fr'
# Saved audio file 'excavators excavators de.mp3' with accent 'de'
# Saved audio file 'excavators excavators it.mp3' with accent 'it'
# Saved audio file 'excavators excavators pt.mp3' with accent 'pt'
# Saved audio file 'excavators excavators ru.mp3' with accent 'ru'
# Saved audio file 'excavators excavators hi.mp3' with accent 'hi'
# Saved audio file 'excavators excavators ja.mp3' with accent 'ja'
# Saved audio file 'excavators excavators zh.mp3' with accent 'zh'
# Saved audio file 'excavators excavators af.mp3' with accent 'af'
# Saved audio file 'excavators excavators sq.mp3' with accent 'sq'
# Saved audio file 'excavators excavators ar.mp3' with accent 'ar'
# Saved audio file 'excavators excavators bn.mp3' with accent 'bn'
# ...
